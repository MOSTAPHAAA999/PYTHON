# %%
import pandas as pd
import os
import zipfile

# Define the zip file path
zip_file_path = "/mnt/data/archive (13).zip"
extract_folder = "/mnt/data/extracted_files"

# Extract the ZIP file
with zipfile.ZipFile(r"C:\Users\mosta\Downloads\archive (13).zip", "r") as zip_ref:
    zip_ref.extractall(extract_folder)

# List all extracted files
csv_files = [f for f in os.listdir(extract_folder) if f.endswith(".csv")]

# Dictionary to store DataFrames
dfs = {}

# Read all CSV files into separate DataFrames
for file in csv_files:
    file_path = os.path.join(extract_folder, file)
    df_name = file.replace(".csv", "")  # Use file name as key
    dfs[df_name] = pd.read_csv(file_path)  # Read CSV file

# Print loaded DataFrames
print(f"Loaded {len(dfs)} CSV files: {list(dfs.keys())}")

# Example: Display first 5 rows of a specific DataFrame
print(dfs["blinkit_delivery_performance"].head())  # Change based on available file names
print(type(dfs))
# Out:
# Loaded 9 CSV files: ['blinkit_customers', 'blinkit_customer_feedback', 'blinkit_delivery_performance', 'blinkit_inventory', 'blinkit_inventoryNew', 'blinkit_marketing_performance', 'blinkit_orders', 'blinkit_order_items', 'blinkit_products']
#      order_id  delivery_partner_id        promised_time          actual_time  \
# 0  1961864118                63230  2024-07-17 08:52:01  2024-07-17 08:47:01
# 1  1549769649                14983  2024-05-28 13:25:29  2024-05-28 13:27:29
# 2  9185164487                39859  2024-09-23 13:25:12  2024-09-23 13:29:12
# 3  9644738826                61497  2023-11-24 16:34:56  2023-11-24 16:33:56
# 4  5427684290                84315  2023-11-20 05:17:39  2023-11-20 05:18:39
#
#    delivery_time_minutes  distance_km delivery_status reasons_if_delayed
# 0                   -5.0         0.96         On Time                NaN
# 1                    2.0         0.98         On Time            Traffic
# 2                    4.0         3.83         On Time            Traffic
# 3                   -1.0         2.76         On Time                NaN
# 4                    1.0         2.63         On Time            Traffic
# <class 'dict'>

# %%
from IPython.display import display

for name, df in dfs.items():
    print(f"📂 Dataset: {name}")
    display(df)  # Display DataFrame in table format
# Out:
# 📂 Dataset: blinkit_customers
#       customer_id      customer_name                        email  \
# 0        97475543      Niharika Nagi       ektataneja@example.org
# 1        22077605       Megha Sachar         vedant45@example.com
# 2        47822591         Hema Bahri        samiazaan@example.com
# 3        79726146         Zaitra Vig        ishanvi87@example.org
# 4        57102800       Januja Verma     atideshpande@example.org
# ...           ...                ...                          ...
# 2495     48002829       Daksh Mandal   varkeymohammed@example.com
# 2496     57392064       Lavanya Jain      deshpandeom@example.com
# 2497     71688530         Umang Dash  gokhalenicholas@example.org
# 2498     89051578    Zinal Natarajan        vyasfrado@example.com
# 2499     78738569  Eiravati Sundaram          onkar24@example.com
#
#              phone                                       address  \
# 0     912987579691           23, Nayar Path, Bihar Sharif-154625
# 1     915123179717           51/302, Buch Chowk\nSrinagar-570271
# 2     910034076149            941\nAnne Street, Darbhanga 186125
# 3     916264232390                43/94, Ghosh, Alappuzha 635655
# 4     917293526596                      06\nOm, Ambarnath 477463
# ...            ...                                           ...
# 2495  919587731286   28/42, Venkataraman Ganj, Kishanganj-360157
# 2496  916137420258                 391, Edwin Path, Korba 202726
# 2497  917595275963                 151, Parmer Ganj\nLoni 906431
# 2498  911994009448  H.No. 172, Khanna Street, Pudukkottai 610564
# 2499  914320353753             H.No. 791, Sur Path\nBally 982559
#
#               area  pincode registration_date customer_segment  total_orders  \
# 0            Udupi   321865        2023-05-13          Premium            13
# 1          Aligarh   149394        2024-06-18         Inactive             4
# 2        Begusarai   621411        2024-09-25          Regular            17
# 3        Kozhikode   826054        2023-10-04              New             4
# 4     Ichalkaranji   730539        2024-03-22         Inactive            14
# ...            ...      ...               ...              ...           ...
# 2495        Mumbai    45238        2024-01-25         Inactive            17
# 2496         Udupi   688100        2024-06-23          Regular             4
# 2497        Kavali   528749        2024-03-18          Regular             1
# 2498         Alwar   586734        2024-09-06          Premium            12
# 2499         Dewas   342448        2023-05-10         Inactive             4
#
#       avg_order_value
# 0              451.92
# 1              825.48
# 2             1969.81
# 3              220.09
# 4              578.14
# ...               ...
# 2495           754.33
# 2496          1540.81
# 2497          1541.22
# 2498          1185.50
# 2499           376.50
#
# [2500 rows x 11 columns]
# 📂 Dataset: blinkit_customer_feedback
#       feedback_id    order_id  customer_id  rating  \
# 0         2234710  1961864118     30065862       4
# 1         5450964  1549769649      9573071       3
# 2          482108  9185164487     45477575       3
# 3         4823104  9644738826     88067569       4
# 4         3537464  5427684290     83298567       3
# ...           ...         ...          ...     ...
# 4995      9024060  1669690997     62600289       3
# 4996      4715968  8340761903     53640286       3
# 4997      9621021  5936301790     87059497       4
# 4998      1134095  5710579377     67310893       4
# 4999      6578433  2494813730     28663279       4
#
#                              feedback_text feedback_category sentiment  \
# 0            It was okay, nothing special.          Delivery   Neutral
# 1                 The order was incorrect.    App Experience  Negative
# 2            It was okay, nothing special.    App Experience   Neutral
# 3         The product met my expectations.    App Experience   Neutral
# 4     Product was damaged during delivery.          Delivery  Negative
# ...                                    ...               ...       ...
# 4995            Taste was not as expected.   Product Quality  Negative
# 4996    Average experience, could improve.   Product Quality   Neutral
# 4997    Average experience, could improve.    App Experience   Neutral
# 4998    Average experience, could improve.          Delivery   Neutral
# 4999         It was okay, nothing special.  Customer Service   Neutral
#
#      feedback_date
# 0       2024-07-17
# 1       2024-05-28
# 2       2024-09-23
# 3       2023-11-24
# 4       2023-11-20
# ...            ...
# 4995    2023-12-25
# 4996    2023-11-27
# 4997    2024-06-21
# 4998    2024-06-06
# 4999    2023-08-23
#
# [5000 rows x 8 columns]
# 📂 Dataset: blinkit_delivery_performance
#         order_id  delivery_partner_id        promised_time  \
# 0     1961864118                63230  2024-07-17 08:52:01
# 1     1549769649                14983  2024-05-28 13:25:29
# 2     9185164487                39859  2024-09-23 13:25:12
# 3     9644738826                61497  2023-11-24 16:34:56
# 4     5427684290                84315  2023-11-20 05:17:39
# ...          ...                  ...                  ...
# 4995  1669690997                90914  2023-12-25 16:05:20
# 4996  8340761903                27952  2023-11-27 09:38:43
# 4997  5936301790                 9590  2024-06-21 19:23:09
# 4998  5710579377                29940  2024-06-06 15:12:13
# 4999  2494813730                32851  2023-08-23 12:20:18
#
#               actual_time  delivery_time_minutes  distance_km delivery_status  \
# 0     2024-07-17 08:47:01                   -5.0         0.96         On Time
# 1     2024-05-28 13:27:29                    2.0         0.98         On Time
# 2     2024-09-23 13:29:12                    4.0         3.83         On Time
# 3     2023-11-24 16:33:56                   -1.0         2.76         On Time
# 4     2023-11-20 05:18:39                    1.0         2.63         On Time
# ...                   ...                    ...          ...             ...
# 4995  2023-12-25 16:10:20                    5.0         1.86         On Time
# 4996  2023-11-27 09:36:43                   -2.0         3.31         On Time
# 4997  2024-06-21 19:26:09                    3.0         2.44         On Time
# 4998  2024-06-06 15:10:13                   -2.0         1.76         On Time
# 4999  2023-08-23 12:21:18                    1.0         2.70         On Time
#
#      reasons_if_delayed
# 0                   NaN
# 1               Traffic
# 2               Traffic
# 3                   NaN
# 4               Traffic
# ...                 ...
# 4995            Traffic
# 4996                NaN
# 4997            Traffic
# 4998                NaN
# 4999            Traffic
#
# [5000 rows x 8 columns]
# 📂 Dataset: blinkit_inventory
#        product_id        date  stock_received  damaged_stock
# 0          153019  17-03-2023               4              2
# 1          848226  17-03-2023               4              2
# 2          965755  17-03-2023               1              0
# 3           39154  17-03-2023               4              0
# 4           34186  17-03-2023               3              2
# ...           ...         ...             ...            ...
# 75167      298985  05-11-2024               3              0
# 75168      679284  05-11-2024               3              0
# 75169      240179  05-11-2024               3              0
# 75170      673058  05-11-2024               3              2
# 75171      114414  05-11-2024               3              0
#
# [75172 rows x 4 columns]
# 📂 Dataset: blinkit_inventoryNew
#        product_id    date  stock_received  damaged_stock
# 0          153019  Mar-23               4              1
# 1          848226  Mar-23               4              1
# 2          965755  Mar-23               1              0
# 3           39154  Mar-23               4              0
# 4           34186  Mar-23               3              1
# ...           ...     ...             ...            ...
# 18100      837480  Nov-24               3              0
# 18101       56589  Nov-24               3              0
# 18102      679284  Nov-24               3              0
# 18103      673058  Nov-24               3              0
# 18104      114414  Nov-24               3              0
#
# [18105 rows x 4 columns]
# 📂 Dataset: blinkit_marketing_performance
#       campaign_id          campaign_name        date target_audience  \
# 0          548299      New User Discount  2024-11-05         Premium
# 1          390914        Weekend Special  2024-11-05        Inactive
# 2          834385         Festival Offer  2024-11-05        Inactive
# 3          241523             Flash Sale  2024-11-05        Inactive
# 4          595111       Membership Drive  2024-11-05       New Users
# ...           ...                    ...         ...             ...
# 5395       381623       Membership Drive  2023-03-17       New Users
# 5396       493317     Category Promotion  2023-03-17         Premium
# 5397       879292  App Push Notification  2023-03-17             All
# 5398       461129         Email Campaign  2023-03-17       New Users
# 5399       282514       Referral Program  2023-03-17       New Users
#
#            channel  impressions  clicks  conversions    spend  \
# 0              App         3130     163           78  1431.85
# 1              App         3925     494           45  4506.34
# 2            Email         7012     370           78  4524.23
# 3              SMS         1115     579           86  3622.79
# 4            Email         7172     795           54  2888.99
# ...            ...          ...     ...          ...      ...
# 5395         Email         8331     809           92  2363.07
# 5396  Social Media         5216     860           34  3922.53
# 5397           App         8480     734           20  1990.75
# 5398         Email         3569     568           10  4246.47
# 5399  Social Media         5967     439           78  1511.93
#
#       revenue_generated  roas
# 0               4777.75  3.60
# 1               6238.11  2.98
# 2               2621.00  2.95
# 3               2955.00  2.84
# 4               8951.81  2.22
# ...                 ...   ...
# 5395            3710.79  1.64
# 5396            7701.25  2.01
# 5397            6650.41  3.98
# 5398            5880.42  2.50
# 5399            8322.01  3.08
#
# [5400 rows x 11 columns]
# 📂 Dataset: blinkit_orders
#         order_id  customer_id           order_date promised_delivery_time  \
# 0     1961864118     30065862  2024-07-17 08:34:01    2024-07-17 08:52:01
# 1     1549769649      9573071  2024-05-28 13:14:29    2024-05-28 13:25:29
# 2     9185164487     45477575  2024-09-23 13:07:12    2024-09-23 13:25:12
# 3     9644738826     88067569  2023-11-24 16:16:56    2023-11-24 16:34:56
# 4     5427684290     83298567  2023-11-20 05:00:39    2023-11-20 05:17:39
# ...          ...          ...                  ...                    ...
# 4995  1669690997     62600289  2023-12-25 15:46:20    2023-12-25 16:05:20
# 4996  8340761903     53640286  2023-11-27 09:18:43    2023-11-27 09:38:43
# 4997  5936301790     87059497  2024-06-21 19:09:09    2024-06-21 19:23:09
# 4998  5710579377     67310893  2024-06-06 14:58:13    2024-06-06 15:12:13
# 4999  2494813730     28663279  2023-08-23 12:04:18    2023-08-23 12:20:18
#
#      actual_delivery_time delivery_status  order_total payment_method  \
# 0     2024-07-17 08:47:01         On Time      3197.07           Cash
# 1     2024-05-28 13:27:29         On Time       976.55           Cash
# 2     2024-09-23 13:29:12         On Time       839.05            UPI
# 3     2023-11-24 16:33:56         On Time       440.23           Card
# 4     2023-11-20 05:18:39         On Time      2526.68           Cash
# ...                   ...             ...          ...            ...
# 4995  2023-12-25 16:10:20         On Time      1132.33           Cash
# 4996  2023-11-27 09:36:43         On Time      2372.01           Cash
# 4997  2024-06-21 19:26:09         On Time      3158.35           Cash
# 4998  2024-06-06 15:10:13         On Time      1918.92            UPI
# 4999  2023-08-23 12:21:18         On Time      1879.46           Card
#
#       delivery_partner_id  store_id
# 0                   63230      4771
# 1                   14983      7534
# 2                   39859      9886
# 3                   61497      7917
# 4                   84315      2741
# ...                   ...       ...
# 4995                90914      1587
# 4996                27952      3458
# 4997                 9590      7424
# 4998                29940      6128
# 4999                32851      5588
#
# [5000 rows x 10 columns]
# 📂 Dataset: blinkit_order_items
#         order_id  product_id  quantity  unit_price
# 0     1961864118      642612         3      517.03
# 1     1549769649      378676         1      881.42
# 2     9185164487      741341         2      923.84
# 3     9644738826      561860         1      874.78
# 4     5427684290      602241         2      976.55
# ...          ...         ...       ...         ...
# 4995  1669690997      925482         3      475.04
# 4996  8340761903      124290         2       39.65
# 4997  5936301790      491314         3      973.44
# 4998  5710579377      319388         2      657.80
# 4999  2494813730      136533         1      826.21
#
# [5000 rows x 4 columns]
# 📂 Dataset: blinkit_products
#      product_id   product_name             category                    brand  \
# 0        153019         Onions  Fruits & Vegetables               Aurora LLC
# 1         11422       Potatoes  Fruits & Vegetables           Ramaswamy-Tata
# 2        669378       Potatoes  Fruits & Vegetables          Chadha and Sons
# 3        848226       Tomatoes  Fruits & Vegetables           Barad and Sons
# 4        890623         Onions  Fruits & Vegetables  Sangha, Nagar and Varty
# ..          ...            ...                  ...                      ...
# 263      444361  Pain Reliever             Pharmacy   Prakash, Bawa and Kale
# 264      679284    Cough Syrup             Pharmacy                 Pant LLC
# 265      240179    Cough Syrup             Pharmacy                 Ram-Suri
# 266      673058    Cough Syrup             Pharmacy              Balan-Madan
# 267      114414       Vitamins             Pharmacy               Kara-Golla
#
#       price      mrp  margin_percentage  shelf_life_days  min_stock_level  \
# 0    947.95  1263.93               25.0                3               13
# 1    127.16   169.55               25.0                3               20
# 2    212.14   282.85               25.0                3               23
# 3    209.59   279.45               25.0                3               10
# 4    354.52   472.69               25.0                3               27
# ..      ...      ...                ...              ...              ...
# 263  822.63  1028.29               20.0              365               20
# 264  877.89  1097.36               20.0              365               28
# 265   90.56   113.20               20.0              365               20
# 266  765.76   957.20               20.0              365               30
# 267  832.06  1040.07               20.0              365               26
#
#      max_stock_level
# 0                 88
# 1                 65
# 2                 70
# 3                 51
# 4                 55
# ..               ...
# 263               71
# 264               95
# 265               56
# 266               94
# 267               66
#
# [268 rows x 10 columns]

# %%
for name, df in dfs.items():
    print(f"📂 Dataset: {name}")
    print(df)  # This prints the full DataFrame
    print("=" * 80)  # Separator for readability
# Out:
# 📂 Dataset: blinkit_customers
#       customer_id      customer_name                        email  \
# 0        97475543      Niharika Nagi       ektataneja@example.org
# 1        22077605       Megha Sachar         vedant45@example.com
# 2        47822591         Hema Bahri        samiazaan@example.com
# 3        79726146         Zaitra Vig        ishanvi87@example.org
# 4        57102800       Januja Verma     atideshpande@example.org
# ...           ...                ...                          ...
# 2495     48002829       Daksh Mandal   varkeymohammed@example.com
# 2496     57392064       Lavanya Jain      deshpandeom@example.com
# 2497     71688530         Umang Dash  gokhalenicholas@example.org
# 2498     89051578    Zinal Natarajan        vyasfrado@example.com
# 2499     78738569  Eiravati Sundaram          onkar24@example.com
#
#              phone                                       address  \
# 0     912987579691           23, Nayar Path, Bihar Sharif-154625
# 1     915123179717           51/302, Buch Chowk\nSrinagar-570271
# 2     910034076149            941\nAnne Street, Darbhanga 186125
# 3     916264232390                43/94, Ghosh, Alappuzha 635655
# 4     917293526596                      06\nOm, Ambarnath 477463
# ...            ...                                           ...
# 2495  919587731286   28/42, Venkataraman Ganj, Kishanganj-360157
# 2496  916137420258                 391, Edwin Path, Korba 202726
# 2497  917595275963                 151, Parmer Ganj\nLoni 906431
# 2498  911994009448  H.No. 172, Khanna Street, Pudukkottai 610564
# 2499  914320353753             H.No. 791, Sur Path\nBally 982559
#
#               area  pincode registration_date customer_segment  total_orders  \
# 0            Udupi   321865        2023-05-13          Premium            13
# 1          Aligarh   149394        2024-06-18         Inactive             4
# 2        Begusarai   621411        2024-09-25          Regular            17
# 3        Kozhikode   826054        2023-10-04              New             4
# 4     Ichalkaranji   730539        2024-03-22         Inactive            14
# ...            ...      ...               ...              ...           ...
# 2495        Mumbai    45238        2024-01-25         Inactive            17
# 2496         Udupi   688100        2024-06-23          Regular             4
# 2497        Kavali   528749        2024-03-18          Regular             1
# 2498         Alwar   586734        2024-09-06          Premium            12
# 2499         Dewas   342448        2023-05-10         Inactive             4
#
#       avg_order_value
# 0              451.92
# 1              825.48
# 2             1969.81
# 3              220.09
# 4              578.14
# ...               ...
# 2495           754.33
# 2496          1540.81
# 2497          1541.22
# 2498          1185.50
# 2499           376.50
#
# [2500 rows x 11 columns]
# ================================================================================
# 📂 Dataset: blinkit_customer_feedback
#       feedback_id    order_id  customer_id  rating  \
# 0         2234710  1961864118     30065862       4
# 1         5450964  1549769649      9573071       3
# 2          482108  9185164487     45477575       3
# 3         4823104  9644738826     88067569       4
# 4         3537464  5427684290     83298567       3
# ...           ...         ...          ...     ...
# 4995      9024060  1669690997     62600289       3
# 4996      4715968  8340761903     53640286       3
# 4997      9621021  5936301790     87059497       4
# 4998      1134095  5710579377     67310893       4
# 4999      6578433  2494813730     28663279       4
#
#                              feedback_text feedback_category sentiment  \
# 0            It was okay, nothing special.          Delivery   Neutral
# 1                 The order was incorrect.    App Experience  Negative
# 2            It was okay, nothing special.    App Experience   Neutral
# 3         The product met my expectations.    App Experience   Neutral
# 4     Product was damaged during delivery.          Delivery  Negative
# ...                                    ...               ...       ...
# 4995            Taste was not as expected.   Product Quality  Negative
# 4996    Average experience, could improve.   Product Quality   Neutral
# 4997    Average experience, could improve.    App Experience   Neutral
# 4998    Average experience, could improve.          Delivery   Neutral
# 4999         It was okay, nothing special.  Customer Service   Neutral
#
#      feedback_date
# 0       2024-07-17
# 1       2024-05-28
# 2       2024-09-23
# 3       2023-11-24
# 4       2023-11-20
# ...            ...
# 4995    2023-12-25
# 4996    2023-11-27
# 4997    2024-06-21
# 4998    2024-06-06
# 4999    2023-08-23
#
# [5000 rows x 8 columns]
# ================================================================================
# 📂 Dataset: blinkit_delivery_performance
#         order_id  delivery_partner_id        promised_time  \
# 0     1961864118                63230  2024-07-17 08:52:01
# 1     1549769649                14983  2024-05-28 13:25:29
# 2     9185164487                39859  2024-09-23 13:25:12
# 3     9644738826                61497  2023-11-24 16:34:56
# 4     5427684290                84315  2023-11-20 05:17:39
# ...          ...                  ...                  ...
# 4995  1669690997                90914  2023-12-25 16:05:20
# 4996  8340761903                27952  2023-11-27 09:38:43
# 4997  5936301790                 9590  2024-06-21 19:23:09
# 4998  5710579377                29940  2024-06-06 15:12:13
# 4999  2494813730                32851  2023-08-23 12:20:18
#
#               actual_time  delivery_time_minutes  distance_km delivery_status  \
# 0     2024-07-17 08:47:01                   -5.0         0.96         On Time
# 1     2024-05-28 13:27:29                    2.0         0.98         On Time
# 2     2024-09-23 13:29:12                    4.0         3.83         On Time
# 3     2023-11-24 16:33:56                   -1.0         2.76         On Time
# 4     2023-11-20 05:18:39                    1.0         2.63         On Time
# ...                   ...                    ...          ...             ...
# 4995  2023-12-25 16:10:20                    5.0         1.86         On Time
# 4996  2023-11-27 09:36:43                   -2.0         3.31         On Time
# 4997  2024-06-21 19:26:09                    3.0         2.44         On Time
# 4998  2024-06-06 15:10:13                   -2.0         1.76         On Time
# 4999  2023-08-23 12:21:18                    1.0         2.70         On Time
#
#      reasons_if_delayed
# 0                   NaN
# 1               Traffic
# 2               Traffic
# 3                   NaN
# 4               Traffic
# ...                 ...
# 4995            Traffic
# 4996                NaN
# 4997            Traffic
# 4998                NaN
# 4999            Traffic
#
# [5000 rows x 8 columns]
# ================================================================================
# 📂 Dataset: blinkit_inventory
#        product_id        date  stock_received  damaged_stock
# 0          153019  17-03-2023               4              2
# 1          848226  17-03-2023               4              2
# 2          965755  17-03-2023               1              0
# 3           39154  17-03-2023               4              0
# 4           34186  17-03-2023               3              2
# ...           ...         ...             ...            ...
# 75167      298985  05-11-2024               3              0
# 75168      679284  05-11-2024               3              0
# 75169      240179  05-11-2024               3              0
# 75170      673058  05-11-2024               3              2
# 75171      114414  05-11-2024               3              0
#
# [75172 rows x 4 columns]
# ================================================================================
# 📂 Dataset: blinkit_inventoryNew
#        product_id    date  stock_received  damaged_stock
# 0          153019  Mar-23               4              1
# 1          848226  Mar-23               4              1
# 2          965755  Mar-23               1              0
# 3           39154  Mar-23               4              0
# 4           34186  Mar-23               3              1
# ...           ...     ...             ...            ...
# 18100      837480  Nov-24               3              0
# 18101       56589  Nov-24               3              0
# 18102      679284  Nov-24               3              0
# 18103      673058  Nov-24               3              0
# 18104      114414  Nov-24               3              0
#
# [18105 rows x 4 columns]
# ================================================================================
# 📂 Dataset: blinkit_marketing_performance
#       campaign_id          campaign_name        date target_audience  \
# 0          548299      New User Discount  2024-11-05         Premium
# 1          390914        Weekend Special  2024-11-05        Inactive
# 2          834385         Festival Offer  2024-11-05        Inactive
# 3          241523             Flash Sale  2024-11-05        Inactive
# 4          595111       Membership Drive  2024-11-05       New Users
# ...           ...                    ...         ...             ...
# 5395       381623       Membership Drive  2023-03-17       New Users
# 5396       493317     Category Promotion  2023-03-17         Premium
# 5397       879292  App Push Notification  2023-03-17             All
# 5398       461129         Email Campaign  2023-03-17       New Users
# 5399       282514       Referral Program  2023-03-17       New Users
#
#            channel  impressions  clicks  conversions    spend  \
# 0              App         3130     163           78  1431.85
# 1              App         3925     494           45  4506.34
# 2            Email         7012     370           78  4524.23
# 3              SMS         1115     579           86  3622.79
# 4            Email         7172     795           54  2888.99
# ...            ...          ...     ...          ...      ...
# 5395         Email         8331     809           92  2363.07
# 5396  Social Media         5216     860           34  3922.53
# 5397           App         8480     734           20  1990.75
# 5398         Email         3569     568           10  4246.47
# 5399  Social Media         5967     439           78  1511.93
#
#       revenue_generated  roas
# 0               4777.75  3.60
# 1               6238.11  2.98
# 2               2621.00  2.95
# 3               2955.00  2.84
# 4               8951.81  2.22
# ...                 ...   ...
# 5395            3710.79  1.64
# 5396            7701.25  2.01
# 5397            6650.41  3.98
# 5398            5880.42  2.50
# 5399            8322.01  3.08
#
# [5400 rows x 11 columns]
# ================================================================================
# 📂 Dataset: blinkit_orders
#         order_id  customer_id           order_date promised_delivery_time  \
# 0     1961864118     30065862  2024-07-17 08:34:01    2024-07-17 08:52:01
# 1     1549769649      9573071  2024-05-28 13:14:29    2024-05-28 13:25:29
# 2     9185164487     45477575  2024-09-23 13:07:12    2024-09-23 13:25:12
# 3     9644738826     88067569  2023-11-24 16:16:56    2023-11-24 16:34:56
# 4     5427684290     83298567  2023-11-20 05:00:39    2023-11-20 05:17:39
# ...          ...          ...                  ...                    ...
# 4995  1669690997     62600289  2023-12-25 15:46:20    2023-12-25 16:05:20
# 4996  8340761903     53640286  2023-11-27 09:18:43    2023-11-27 09:38:43
# 4997  5936301790     87059497  2024-06-21 19:09:09    2024-06-21 19:23:09
# 4998  5710579377     67310893  2024-06-06 14:58:13    2024-06-06 15:12:13
# 4999  2494813730     28663279  2023-08-23 12:04:18    2023-08-23 12:20:18
#
#      actual_delivery_time delivery_status  order_total payment_method  \
# 0     2024-07-17 08:47:01         On Time      3197.07           Cash
# 1     2024-05-28 13:27:29         On Time       976.55           Cash
# 2     2024-09-23 13:29:12         On Time       839.05            UPI
# 3     2023-11-24 16:33:56         On Time       440.23           Card
# 4     2023-11-20 05:18:39         On Time      2526.68           Cash
# ...                   ...             ...          ...            ...
# 4995  2023-12-25 16:10:20         On Time      1132.33           Cash
# 4996  2023-11-27 09:36:43         On Time      2372.01           Cash
# 4997  2024-06-21 19:26:09         On Time      3158.35           Cash
# 4998  2024-06-06 15:10:13         On Time      1918.92            UPI
# 4999  2023-08-23 12:21:18         On Time      1879.46           Card
#
#       delivery_partner_id  store_id
# 0                   63230      4771
# 1                   14983      7534
# 2                   39859      9886
# 3                   61497      7917
# 4                   84315      2741
# ...                   ...       ...
# 4995                90914      1587
# 4996                27952      3458
# 4997                 9590      7424
# 4998                29940      6128
# 4999                32851      5588
#
# [5000 rows x 10 columns]
# ================================================================================
# 📂 Dataset: blinkit_order_items
#         order_id  product_id  quantity  unit_price
# 0     1961864118      642612         3      517.03
# 1     1549769649      378676         1      881.42
# 2     9185164487      741341         2      923.84
# 3     9644738826      561860         1      874.78
# 4     5427684290      602241         2      976.55
# ...          ...         ...       ...         ...
# 4995  1669690997      925482         3      475.04
# 4996  8340761903      124290         2       39.65
# 4997  5936301790      491314         3      973.44
# 4998  5710579377      319388         2      657.80
# 4999  2494813730      136533         1      826.21
#
# [5000 rows x 4 columns]
# ================================================================================
# 📂 Dataset: blinkit_products
#      product_id   product_name             category                    brand  \
# 0        153019         Onions  Fruits & Vegetables               Aurora LLC
# 1         11422       Potatoes  Fruits & Vegetables           Ramaswamy-Tata
# 2        669378       Potatoes  Fruits & Vegetables          Chadha and Sons
# 3        848226       Tomatoes  Fruits & Vegetables           Barad and Sons
# 4        890623         Onions  Fruits & Vegetables  Sangha, Nagar and Varty
# ..          ...            ...                  ...                      ...
# 263      444361  Pain Reliever             Pharmacy   Prakash, Bawa and Kale
# 264      679284    Cough Syrup             Pharmacy                 Pant LLC
# 265      240179    Cough Syrup             Pharmacy                 Ram-Suri
# 266      673058    Cough Syrup             Pharmacy              Balan-Madan
# 267      114414       Vitamins             Pharmacy               Kara-Golla
#
#       price      mrp  margin_percentage  shelf_life_days  min_stock_level  \
# 0    947.95  1263.93               25.0                3               13
# 1    127.16   169.55               25.0                3               20
# 2    212.14   282.85               25.0                3               23
# 3    209.59   279.45               25.0                3               10
# 4    354.52   472.69               25.0                3               27
# ..      ...      ...                ...              ...              ...
# 263  822.63  1028.29               20.0              365               20
# 264  877.89  1097.36               20.0              365               28
# 265   90.56   113.20               20.0              365               20
# 266  765.76   957.20               20.0              365               30
# 267  832.06  1040.07               20.0              365               26
#
#      max_stock_level
# 0                 88
# 1                 65
# 2                 70
# 3                 51
# 4                 55
# ..               ...
# 263               71
# 264               95
# 265               56
# 266               94
# 267               66
#
# [268 rows x 10 columns]
# ================================================================================

# %%
dfs["blinkit_delivery_performance"].to_csv("blinkit_delivery_performance.csv", index=False)
dfs['blinkit_delivery_performance']
dfs_on_time = dfs['blinkit_delivery_performance'][dfs['blinkit_delivery_performance']['delivery_status'] == 'On Time'].copy()
dfs_on_time
# Out:
#         order_id  delivery_partner_id        promised_time  \
# 0     1961864118                63230  2024-07-17 08:52:01
# 1     1549769649                14983  2024-05-28 13:25:29
# 2     9185164487                39859  2024-09-23 13:25:12
# 3     9644738826                61497  2023-11-24 16:34:56
# 4     5427684290                84315  2023-11-20 05:17:39
# ...          ...                  ...                  ...
# 4995  1669690997                90914  2023-12-25 16:05:20
# 4996  8340761903                27952  2023-11-27 09:38:43
# 4997  5936301790                 9590  2024-06-21 19:23:09
# 4998  5710579377                29940  2024-06-06 15:12:13
# 4999  2494813730                32851  2023-08-23 12:20:18
#
#               actual_time  delivery_time_minutes  distance_km delivery_status  \
# 0     2024-07-17 08:47:01                   -5.0         0.96         On Time
# 1     2024-05-28 13:27:29                    2.0         0.98         On Time
# 2     2024-09-23 13:29:12                    4.0         3.83         On Time
# 3     2023-11-24 16:33:56                   -1.0         2.76         On Time
# 4     2023-11-20 05:18:39                    1.0         2.63         On Time
# ...                   ...                    ...          ...             ...
# 4995  2023-12-25 16:10:20                    5.0         1.86         On Time
# 4996  2023-11-27 09:36:43                   -2.0         3.31         On Time
# 4997  2024-06-21 19:26:09                    3.0         2.44         On Time
# 4998  2024-06-06 15:10:13                   -2.0         1.76         On Time
# 4999  2023-08-23 12:21:18                    1.0         2.70         On Time
#
#      reasons_if_delayed
# 0                   NaN
# 1               Traffic
# 2               Traffic
# 3                   NaN
# 4               Traffic
# ...                 ...
# 4995            Traffic
# 4996                NaN
# 4997            Traffic
# 4998                NaN
# 4999            Traffic
#
# [3470 rows x 8 columns]

# %%
dfs['blinkit_delivery_performance']['delivery_status'].value_counts()
# Out:
# delivery_status
# On Time                  3470
# Slightly Delayed         1037
# Significantly Delayed     493
# Name: count, dtype: int64

# %%
dfs_delayed = dfs['blinkit_delivery_performance'][
	(dfs['blinkit_delivery_performance']['delivery_status'] == 'Slightly Delayed') |
	(dfs['blinkit_delivery_performance']['delivery_status'] == 'Significantly Delayed')
].copy()
dfs_delayed
# Out:
#         order_id  delivery_partner_id        promised_time  \
# 9      374186990                77203  2023-08-09 01:37:30
# 12    9171116867                73907  2023-10-22 11:25:33
# 13    5504941865                56077  2024-01-28 02:55:11
# 16    8195544338                  102  2023-04-26 04:20:57
# 19    4656471694                62782  2023-12-09 08:27:08
# ...          ...                  ...                  ...
# 4962  7415765726                80897  2023-08-05 09:36:31
# 4971  6457122136                18328  2023-05-19 07:54:24
# 4977  5562576298                77071  2023-11-08 13:41:27
# 4978  7446009755                72606  2023-06-15 21:08:56
# 4984  2520527893                59389  2024-10-02 01:53:34
#
#               actual_time  delivery_time_minutes  distance_km  \
# 9     2023-08-09 01:44:30                    7.0         1.47
# 12    2023-10-22 11:37:33                   12.0         2.23
# 13    2024-01-28 03:06:11                   11.0         4.45
# 16    2023-04-26 04:28:57                    8.0         1.16
# 19    2023-12-09 08:35:08                    8.0         3.70
# ...                   ...                    ...          ...
# 4962  2023-08-05 09:51:31                   15.0         4.38
# 4971  2023-05-19 08:19:24                   25.0         1.90
# 4977  2023-11-08 13:48:27                    7.0         3.40
# 4978  2023-06-15 21:19:56                   11.0         4.92
# 4984  2024-10-02 02:10:34                   17.0         1.14
#
#             delivery_status reasons_if_delayed
# 9          Slightly Delayed            Traffic
# 12         Slightly Delayed            Traffic
# 13         Slightly Delayed            Traffic
# 16         Slightly Delayed            Traffic
# 19         Slightly Delayed            Traffic
# ...                     ...                ...
# 4962       Slightly Delayed            Traffic
# 4971  Significantly Delayed            Traffic
# 4977       Slightly Delayed            Traffic
# 4978       Slightly Delayed            Traffic
# 4984  Significantly Delayed            Traffic
#
# [1530 rows x 8 columns]

# %%
# Convert 'actual_time' to datetime
dfs_delayed['actual_time'] = pd.to_datetime(dfs_delayed['actual_time'])

# Extract time from 'actual_time'
dfs_delayed['delivery_time_'] = dfs_delayed['actual_time'].dt.time
dfs_delayed['delivery_time_']
dfs_delayed
# Out:
#         order_id  delivery_partner_id        promised_time  \
# 9      374186990                77203  2023-08-09 01:37:30
# 12    9171116867                73907  2023-10-22 11:25:33
# 13    5504941865                56077  2024-01-28 02:55:11
# 16    8195544338                  102  2023-04-26 04:20:57
# 19    4656471694                62782  2023-12-09 08:27:08
# ...          ...                  ...                  ...
# 4962  7415765726                80897  2023-08-05 09:36:31
# 4971  6457122136                18328  2023-05-19 07:54:24
# 4977  5562576298                77071  2023-11-08 13:41:27
# 4978  7446009755                72606  2023-06-15 21:08:56
# 4984  2520527893                59389  2024-10-02 01:53:34
#
#              actual_time  delivery_time_minutes  distance_km  \
# 9    2023-08-09 01:44:30                    7.0         1.47
# 12   2023-10-22 11:37:33                   12.0         2.23
# 13   2024-01-28 03:06:11                   11.0         4.45
# 16   2023-04-26 04:28:57                    8.0         1.16
# 19   2023-12-09 08:35:08                    8.0         3.70
# ...                  ...                    ...          ...
# 4962 2023-08-05 09:51:31                   15.0         4.38
# 4971 2023-05-19 08:19:24                   25.0         1.90
# 4977 2023-11-08 13:48:27                    7.0         3.40
# 4978 2023-06-15 21:19:56                   11.0         4.92
# 4984 2024-10-02 02:10:34                   17.0         1.14
#
#             delivery_status reasons_if_delayed delivery_time_
# 9          Slightly Delayed            Traffic       01:44:30
# 12         Slightly Delayed            Traffic       11:37:33
# 13         Slightly Delayed            Traffic       03:06:11
# 16         Slightly Delayed            Traffic       04:28:57
# 19         Slightly Delayed            Traffic       08:35:08
# ...                     ...                ...            ...
# 4962       Slightly Delayed            Traffic       09:51:31
# 4971  Significantly Delayed            Traffic       08:19:24
# 4977       Slightly Delayed            Traffic       13:48:27
# 4978       Slightly Delayed            Traffic       21:19:56
# 4984  Significantly Delayed            Traffic       02:10:34
#
# [1530 rows x 9 columns]

# %%
# Convert order_time to datetime and extract hour
dfs['blinkit_orders']['order_time'] = pd.to_datetime(dfs['blinkit_orders']['order_date'])
dfs['blinkit_orders']['hour'] = dfs['blinkit_orders']['order_time'].dt.hour

# Filter delayed orders
delayed_orders = dfs['blinkit_delivery_performance'][dfs['blinkit_delivery_performance']['delivery_status'].str.contains('Delayed')]

# Merge with blinkit_orders to get the 'hour' column
delayed_orders = delayed_orders.merge(dfs['blinkit_orders'][['order_id', 'hour']], on='order_id', how='left')

# Count delayed orders per hour
time_slot_delays = delayed_orders['hour'].value_counts().sort_index()

# Find the hour with the most delays
peak_delay_hour = time_slot_delays.idxmax()
max_delays = time_slot_delays.max()

# Convert 24-hour format to 12-hour AM/PM format
def format_hour(hour):
    if hour == 0:
        return "12 AM"
    elif hour == 12:
        return "12 PM"
    elif hour < 12:
        return f"{hour} AM"
    else:
        return f"{hour - 12} PM"

# Display results
peak_hour_formatted = format_hour(peak_delay_hour)
print(f"The peak delay hour is {peak_hour_formatted} with {max_delays} delayed orders.")
# Out:
# The peak delay hour is 1 PM with 88 delayed orders.

# %%
def format_hour(hour):
    if hour == 0:
        return "12 AM"
    elif hour == 12:
        return "12 PM"
    elif hour < 12:
        return f"{hour} AM"
    else:
        return f"{hour - 12} PM"

# Apply time conversion
delayed_orders['formatted_hour'] = delayed_orders['hour'].apply(format_hour)

# Create a Pivot Table: Index = formatted_hour, Columns = delivery_status, Values = Count of Orders
pivot_table = delayed_orders.pivot_table(index="formatted_hour", columns="delivery_status", aggfunc="size", fill_value=0)

# Sort the index in correct AM/PM order
time_order = ["12 AM"] + [f"{i} AM" for i in range(1, 12)] + ["12 PM"] + [f"{i} PM" for i in range(1, 12)]
pivot_table = pivot_table.reindex(time_order)

# Display the Pivot Table
pivot_table
# Out:
# delivery_status  Significantly Delayed  Slightly Delayed
# formatted_hour
# 12 AM                               19                50
# 1 AM                                20                42
# 2 AM                                29                34
# 3 AM                                16                44
# 4 AM                                24                48
# 5 AM                                28                37
# 6 AM                                20                43
# 7 AM                                23                46
# 8 AM                                26                41
# 9 AM                                16                37
# 10 AM                               24                34
# 11 AM                               19                49
# 12 PM                               23                36
# 1 PM                                27                61
# 2 PM                                13                40
# 3 PM                                12                56
# 4 PM                                16                38
# 5 PM                                15                41
# 6 PM                                25                46
# 7 PM                                21                51
# 8 PM                                22                42
# 9 PM                                20                32
# 10 PM                               21                53
# 11 PM                               14                36

# %%
pivot_table.plot(kind='bar',
                    figsize=(14, 8),
                    title='Delayed Orders by Hour',
                    xlabel='Delivery Status',
                    ylabel='Number of Orders',
                    color=['#720455', '#E8BCB9'],
                    stacked=True
                )
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 9
#       1 pivot_table.plot(kind='bar',
#       2                     figsize=(14, 8),
#       3                     title='Delayed Orders by Hour',
#    (...)
#       7                     stacked=True
#       8                 )
# ----> 9 plt.show()
#
# NameError: name 'plt' is not defined

# %%
import pandas as pd
import os
import zipfile

# Define the zip file path
zip_file_path = "/mnt/data/archive (13).zip"
extract_folder = "/mnt/data/extracted_files"

# Extract the ZIP file
with zipfile.ZipFile(r"C:\Users\mosta\Downloads\archive (13).zip", "r") as zip_ref:
    zip_ref.extractall(extract_folder)

# List all extracted files
csv_files = [f for f in os.listdir(extract_folder) if f.endswith(".csv")]

# Dictionary to store DataFrames
dfs = {}

# Read all CSV files into separate DataFrames
for file in csv_files:
    file_path = os.path.join(extract_folder, file)
    df_name = file.replace(".csv", "")  # Use file name as key
    dfs[df_name] = pd.read_csv(file_path)  # Read CSV file

# Print loaded DataFrames
print(f"Loaded {len(dfs)} CSV files: {list(dfs.keys())}")

# Example: Display first 5 rows of a specific DataFrame
print(dfs["blinkit_delivery_performance"].head())  # Change based on available file names
print(type(dfs))
# Out:
# Loaded 9 CSV files: ['blinkit_customers', 'blinkit_customer_feedback', 'blinkit_delivery_performance', 'blinkit_inventory', 'blinkit_inventoryNew', 'blinkit_marketing_performance', 'blinkit_orders', 'blinkit_order_items', 'blinkit_products']
#      order_id  delivery_partner_id        promised_time          actual_time  \
# 0  1961864118                63230  2024-07-17 08:52:01  2024-07-17 08:47:01
# 1  1549769649                14983  2024-05-28 13:25:29  2024-05-28 13:27:29
# 2  9185164487                39859  2024-09-23 13:25:12  2024-09-23 13:29:12
# 3  9644738826                61497  2023-11-24 16:34:56  2023-11-24 16:33:56
# 4  5427684290                84315  2023-11-20 05:17:39  2023-11-20 05:18:39
#
#    delivery_time_minutes  distance_km delivery_status reasons_if_delayed
# 0                   -5.0         0.96         On Time                NaN
# 1                    2.0         0.98         On Time            Traffic
# 2                    4.0         3.83         On Time            Traffic
# 3                   -1.0         2.76         On Time                NaN
# 4                    1.0         2.63         On Time            Traffic
# <class 'dict'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Convert order time to datetime and extract hours
dfs['blinkit_orders']['order_time'] = pd.to_datetime(dfs['blinkit_orders']['order_date'])
dfs['blinkit_orders']['hour'] = dfs['blinkit_orders']['order_time'].dt.hour

# Filter delayed orders
delayed_orders = dfs['blinkit_delivery_performance'][dfs['blinkit_delivery_performance']['delivery_status'].str.contains('Delayed')]

# Merge to get hour column
delayed_orders = delayed_orders.merge(dfs['blinkit_orders'][['order_id', 'hour']], on='order_id', how='left')

# Count delayed orders per hour
time_slot_delays = delayed_orders['hour'].value_counts().sort_index()

# Identify peak delay hour
peak_delay_hour = time_slot_delays.idxmax()
max_delays = time_slot_delays.max()

print(f"Peak delay hour: {peak_delay_hour}:00 with {max_delays} delays.")

# Convert 24-hour format to 12-hour AM/PM format
def format_hour(hour):
    if hour == 0:
        return "12 AM"
    elif hour == 12:
        return "12 PM"
    elif hour < 12:
        return f"{hour} AM"
    else:
        return f"{hour - 12} PM"

# Create formatted x-axis labels
formatted_hours = [format_hour(h) for h in time_slot_delays.index]

# Plot setup
plt.figure(figsize=(12, 6))

# Define colors and highlight peak
colors = ["lightcoral" if h == peak_delay_hour else "steelblue" for h in time_slot_delays.index]

bars = plt.bar(time_slot_delays.index, time_slot_delays.values + 5, color=colors)  # Offset by +5 to move bars up

# Annotate peak delay hour
plt.text(peak_delay_hour, max_delays + 10, f"Peak: {max_delays}", 
         fontsize=12, fontweight="bold", ha="center", color="black")

# Labels and title
plt.xlabel("Hour of the Day", fontsize=14, fontweight="bold")
plt.ylabel("Number of Delayed Orders", fontsize=14, fontweight="bold")
plt.title("Delayed Orders per Time Slot", fontsize=16, fontweight="bold", color="darkblue")

# Format x-axis with 12-hour format
plt.xticks(ticks=time_slot_delays.index, labels=formatted_hours, rotation=45)

# Grid and layout adjustments
plt.grid(axis="y", linestyle="--", alpha=0.6)
plt.ylim(0, max_delays + 20)  # Adjust limit to prevent overlap

# Show final plot
plt.show()
# Out:
# Peak delay hour: 13:00 with 88 delays.

# %%
# Ensure 'actual_time' is in datetime format
dfs_delayed['actual_time'] = pd.to_datetime(dfs_delayed['actual_time'])

# Extract year and month
dfs_delayed['delivery_year_month'] = dfs_delayed['actual_time'].dt.to_period('M')

# Display the updated DataFrame
dfs_delayed
# Out:
#         order_id  delivery_partner_id        promised_time  \
# 9      374186990                77203  2023-08-09 01:37:30
# 12    9171116867                73907  2023-10-22 11:25:33
# 13    5504941865                56077  2024-01-28 02:55:11
# 16    8195544338                  102  2023-04-26 04:20:57
# 19    4656471694                62782  2023-12-09 08:27:08
# ...          ...                  ...                  ...
# 4962  7415765726                80897  2023-08-05 09:36:31
# 4971  6457122136                18328  2023-05-19 07:54:24
# 4977  5562576298                77071  2023-11-08 13:41:27
# 4978  7446009755                72606  2023-06-15 21:08:56
# 4984  2520527893                59389  2024-10-02 01:53:34
#
#              actual_time  delivery_time_minutes  distance_km  \
# 9    2023-08-09 01:44:30                    7.0         1.47
# 12   2023-10-22 11:37:33                   12.0         2.23
# 13   2024-01-28 03:06:11                   11.0         4.45
# 16   2023-04-26 04:28:57                    8.0         1.16
# 19   2023-12-09 08:35:08                    8.0         3.70
# ...                  ...                    ...          ...
# 4962 2023-08-05 09:51:31                   15.0         4.38
# 4971 2023-05-19 08:19:24                   25.0         1.90
# 4977 2023-11-08 13:48:27                    7.0         3.40
# 4978 2023-06-15 21:19:56                   11.0         4.92
# 4984 2024-10-02 02:10:34                   17.0         1.14
#
#             delivery_status reasons_if_delayed delivery_time_  \
# 9          Slightly Delayed            Traffic       01:44:30
# 12         Slightly Delayed            Traffic       11:37:33
# 13         Slightly Delayed            Traffic       03:06:11
# 16         Slightly Delayed            Traffic       04:28:57
# 19         Slightly Delayed            Traffic       08:35:08
# ...                     ...                ...            ...
# 4962       Slightly Delayed            Traffic       09:51:31
# 4971  Significantly Delayed            Traffic       08:19:24
# 4977       Slightly Delayed            Traffic       13:48:27
# 4978       Slightly Delayed            Traffic       21:19:56
# 4984  Significantly Delayed            Traffic       02:10:34
#
#      delivery_year_month
# 9                2023-08
# 12               2023-10
# 13               2024-01
# 16               2023-04
# 19               2023-12
# ...                  ...
# 4962             2023-08
# 4971             2023-05
# 4977             2023-11
# 4978             2023-06
# 4984             2024-10
#
# [1530 rows x 10 columns]

# %%
import pandas as pd

# Ensure 'actual_time' is in datetime format
dfs_delayed['actual_time'] = pd.to_datetime(dfs_delayed['actual_time'])

# Create a 'Year-Month' column
dfs_delayed['year_month'] = dfs_delayed['actual_time'].dt.to_period('M')

# Create a pivot table
pivot_table_date = dfs_delayed.pivot_table(index='year_month', 
                                      columns='delivery_status', 
                                      values='order_id', 
                                      aggfunc='count', 
                                      fill_value=0)

pivot_table_date
# Out:
# delivery_status  Significantly Delayed  Slightly Delayed
# year_month
# 2023-03                             10                30
# 2023-04                             20                55
# 2023-05                             24                63
# 2023-06                             18                38
# 2023-07                             14                59
# 2023-08                             20                63
# 2023-09                             26                47
# 2023-10                             27                40
# 2023-11                             38                59
# 2023-12                             36                53
# 2024-01                             31                48
# 2024-02                             24                58
# 2024-03                             20                54
# 2024-04                             19                43
# 2024-05                             33                52
# 2024-06                             28                41
# 2024-07                             23                62
# 2024-08                             24                54
# 2024-09                             26                54
# 2024-10                             29                57
# 2024-11                              3                 7

# %%
import matplotlib.pyplot as plt

# Sort the pivot table by index in descending order
pivot_table_date = pivot_table_date.sort_index(ascending=False)

# Plot the sorted pivot table
pivot_table_date.plot(kind='barh', figsize=(20,15), title='Delayed Orders monthly')
plt.legend(title='Delivery Status', title_fontsize='13', fontsize='12', loc='upper right')
plt.show()

# %%
dfs['blinkit_orders']
# Out:
#         order_id  customer_id           order_date promised_delivery_time  \
# 0     1961864118     30065862  2024-07-17 08:34:01    2024-07-17 08:52:01
# 1     1549769649      9573071  2024-05-28 13:14:29    2024-05-28 13:25:29
# 2     9185164487     45477575  2024-09-23 13:07:12    2024-09-23 13:25:12
# 3     9644738826     88067569  2023-11-24 16:16:56    2023-11-24 16:34:56
# 4     5427684290     83298567  2023-11-20 05:00:39    2023-11-20 05:17:39
# ...          ...          ...                  ...                    ...
# 4995  1669690997     62600289  2023-12-25 15:46:20    2023-12-25 16:05:20
# 4996  8340761903     53640286  2023-11-27 09:18:43    2023-11-27 09:38:43
# 4997  5936301790     87059497  2024-06-21 19:09:09    2024-06-21 19:23:09
# 4998  5710579377     67310893  2024-06-06 14:58:13    2024-06-06 15:12:13
# 4999  2494813730     28663279  2023-08-23 12:04:18    2023-08-23 12:20:18
#
#      actual_delivery_time delivery_status  order_total payment_method  \
# 0     2024-07-17 08:47:01         On Time      3197.07           Cash
# 1     2024-05-28 13:27:29         On Time       976.55           Cash
# 2     2024-09-23 13:29:12         On Time       839.05            UPI
# 3     2023-11-24 16:33:56         On Time       440.23           Card
# 4     2023-11-20 05:18:39         On Time      2526.68           Cash
# ...                   ...             ...          ...            ...
# 4995  2023-12-25 16:10:20         On Time      1132.33           Cash
# 4996  2023-11-27 09:36:43         On Time      2372.01           Cash
# 4997  2024-06-21 19:26:09         On Time      3158.35           Cash
# 4998  2024-06-06 15:10:13         On Time      1918.92            UPI
# 4999  2023-08-23 12:21:18         On Time      1879.46           Card
#
#       delivery_partner_id  store_id          order_time  hour
# 0                   63230      4771 2024-07-17 08:34:01     8
# 1                   14983      7534 2024-05-28 13:14:29    13
# 2                   39859      9886 2024-09-23 13:07:12    13
# 3                   61497      7917 2023-11-24 16:16:56    16
# 4                   84315      2741 2023-11-20 05:00:39     5
# ...                   ...       ...                 ...   ...
# 4995                90914      1587 2023-12-25 15:46:20    15
# 4996                27952      3458 2023-11-27 09:18:43     9
# 4997                 9590      7424 2024-06-21 19:09:09    19
# 4998                29940      6128 2024-06-06 14:58:13    14
# 4999                32851      5588 2023-08-23 12:04:18    12
#
# [5000 rows x 12 columns]

# %%
pivot_orders = dfs['blinkit_orders'].pivot_table(index='customer_id',columns='delivery_status',values='order_id',aggfunc='count')   
pivot_orders
# Out:
# delivery_status  On Time  Significantly Delayed  Slightly Delayed
# customer_id
# 31813                1.0                    NaN               1.0
# 61020                2.0                    1.0               NaN
# 119099               1.0                    NaN               3.0
# 188838               1.0                    NaN               1.0
# 191616               NaN                    NaN               2.0
# ...                  ...                    ...               ...
# 99734256             3.0                    NaN               NaN
# 99772709             2.0                    1.0               NaN
# 99784559             1.0                    NaN               NaN
# 99824171             1.0                    1.0               NaN
# 99893898             1.0                    2.0               1.0
#
# [2172 rows x 3 columns]

# %%
pivot_orders.fillna(0, inplace=True)
pivot_orders
pivot_orders['total_orders']=pivot_orders['On Time']+pivot_orders['Slightly Delayed']+pivot_orders['Significantly Delayed']
pivot_orders
# Out:
# delivery_status  On Time  Significantly Delayed  Slightly Delayed  \
# customer_id
# 31813                1.0                    0.0               1.0
# 61020                2.0                    1.0               0.0
# 119099               1.0                    0.0               3.0
# 188838               1.0                    0.0               1.0
# 191616               0.0                    0.0               2.0
# ...                  ...                    ...               ...
# 99734256             3.0                    0.0               0.0
# 99772709             2.0                    1.0               0.0
# 99784559             1.0                    0.0               0.0
# 99824171             1.0                    1.0               0.0
# 99893898             1.0                    2.0               1.0
#
# delivery_status  total_orders
# customer_id
# 31813                     2.0
# 61020                     3.0
# 119099                    4.0
# 188838                    2.0
# 191616                    2.0
# ...                       ...
# 99734256                  3.0
# 99772709                  3.0
# 99784559                  1.0
# 99824171                  2.0
# 99893898                  4.0
#
# [2172 rows x 4 columns]

# %%
pivot_orders.sort_values(by='total_orders',ascending=False,inplace=True)
pivot_orders
# Out:
# delivery_status  On Time  Significantly Delayed  Slightly Delayed  \
# customer_id
# 77869660             5.0                    1.0               3.0
# 17805991             7.0                    0.0               1.0
# 8791577              4.0                    1.0               3.0
# 93018527             6.0                    0.0               1.0
# 12832151             4.0                    2.0               1.0
# ...                  ...                    ...               ...
# 98144693             0.0                    0.0               1.0
# 1655637              1.0                    0.0               0.0
# 1497747              1.0                    0.0               0.0
# 99594960             0.0                    0.0               1.0
# 99412119             0.0                    0.0               1.0
#
# delivery_status  total_orders
# customer_id
# 77869660                  9.0
# 17805991                  8.0
# 8791577                   8.0
# 93018527                  7.0
# 12832151                  7.0
# ...                       ...
# 98144693                  1.0
# 1655637                   1.0
# 1497747                   1.0
# 99594960                  1.0
# 99412119                  1.0
#
# [2172 rows x 4 columns]

# %%
TOP_CUSTOMERS = pivot_orders.head(10)
TOP_CUSTOMERS
# Out:
# delivery_status  On Time  Significantly Delayed  Slightly Delayed  \
# customer_id
# 77869660             5.0                    1.0               3.0
# 17805991             7.0                    0.0               1.0
# 8791577              4.0                    1.0               3.0
# 93018527             6.0                    0.0               1.0
# 12832151             4.0                    2.0               1.0
# 75213636             6.0                    0.0               1.0
# 10562528             5.0                    0.0               2.0
# 13604883             4.0                    1.0               2.0
# 21701991             5.0                    1.0               1.0
# 25128143             4.0                    1.0               2.0
#
# delivery_status  total_orders
# customer_id
# 77869660                  9.0
# 17805991                  8.0
# 8791577                   8.0
# 93018527                  7.0
# 12832151                  7.0
# 75213636                  7.0
# 10562528                  7.0
# 13604883                  7.0
# 21701991                  7.0
# 25128143                  7.0

# %%
pivot_orders
# Out:
# delivery_status  On Time  Significantly Delayed  Slightly Delayed  \
# customer_id
# 77869660             5.0                    1.0               3.0
# 17805991             7.0                    0.0               1.0
# 8791577              4.0                    1.0               3.0
# 93018527             6.0                    0.0               1.0
# 12832151             4.0                    2.0               1.0
# ...                  ...                    ...               ...
# 98144693             0.0                    0.0               1.0
# 1655637              1.0                    0.0               0.0
# 1497747              1.0                    0.0               0.0
# 99594960             0.0                    0.0               1.0
# 99412119             0.0                    0.0               1.0
#
# delivery_status  total_orders
# customer_id
# 77869660                  9.0
# 17805991                  8.0
# 8791577                   8.0
# 93018527                  7.0
# 12832151                  7.0
# ...                       ...
# 98144693                  1.0
# 1655637                   1.0
# 1497747                   1.0
# 99594960                  1.0
# 99412119                  1.0
#
# [2172 rows x 4 columns]

# %%
# %pip install Jinja2

pivot_orders['delayed'] = (pivot_orders['Slightly Delayed'] + pivot_orders['Significantly Delayed']) / pivot_orders['total_orders'] * 100
pivot_orders['delayed'] = pivot_orders['delayed'].apply(lambda x: "{:.2f}%".format(x))
pivot_orders.style.format({'delayed': '{:.2f}%'})
pivot_orders.drop(columns='dealyed', inplace=True)  
pivot_orders
# Out:
# Requirement already satisfied: Jinja2 in c:\users\mosta\anaconda3\envs\envname\lib\site-packages (3.1.5)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\mosta\anaconda3\envs\envname\lib\site-packages (from Jinja2) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 6
#       4 pivot_orders['delayed'] = pivot_orders['delayed'].apply(lambda x: "{:.2f}%".format(x))
#       5 pivot_orders.style.format({'delayed': '{:.2f}%'})
# ----> 6 pivot_orders.drop(columns='dealyed', inplace=True)
#       7 pivot_orders
#
# File c:\Users\mosta\Anaconda3\envs\ENVNAME\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File c:\Users\mosta\Anaconda3\envs\ENVNAME\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File c:\Users\mosta\Anaconda3\envs\ENVNAME\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File c:\Users\mosta\Anaconda3\envs\ENVNAME\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['dealyed'] not found in axis"

# %%
TOP_CUSTOMERS.drop(columns='total_orders', inplace=True)
pivot_orders
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 TOP_CUSTOMERS.drop(columns='total_orders', inplace=True)
#       2 pivot_orders
#
# File c:\Users\mosta\Anaconda3\envs\ENVNAME\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File c:\Users\mosta\Anaconda3\envs\ENVNAME\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File c:\Users\mosta\Anaconda3\envs\ENVNAME\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File c:\Users\mosta\Anaconda3\envs\ENVNAME\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['total_orders'] not found in axis"
